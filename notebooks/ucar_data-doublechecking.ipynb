# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import completions_module as cmodule

# %%
# ucar list
all_files = glob.glob("../data/completions_*.csv")
all_files = sorted(all_files)

# %%
all_files
# Out:
# ['../data/completions_2009.csv',
#  '../data/completions_2010.csv',
#  '../data/completions_2011.csv',
#  '../data/completions_2012.csv',
#  '../data/completions_2013.csv',
#  '../data/completions_2014.csv',
#  '../data/completions_2015.csv',
#  '../data/completions_2016.csv',
#  '../data/completions_2017.csv',
#  '../data/completions_2018.csv',
#  '../data/completions_2019.csv',
#  '../data/completions_2020.csv']

# %%
csv_2009 = pd.read_csv(all_files[0])
csv_2010 = pd.read_csv(all_files[1])
csv_2011 = pd.read_csv(all_files[2])
csv_2012 = pd.read_csv(all_files[3])
csv_2013 = pd.read_csv(all_files[4])
csv_2014 = pd.read_csv(all_files[5])
csv_2015 = pd.read_csv(all_files[6])
csv_2016 = pd.read_csv(all_files[7])
csv_2017 = pd.read_csv(all_files[8])
csv_2018 = pd.read_csv(all_files[9])
csv_2019 = pd.read_csv(all_files[10])
csv_2020 = pd.read_csv(all_files[11])

# %%
csv_2009['institution name'].unique()
# Out:
# array(['Alabama A & M University', 'University of Alabama in Huntsville',
#        'The University of Alabama', 'Miles College',
#        'University of South Alabama', 'Tuskegee University',
#        'University of Alaska Fairbanks', 'Arizona State University-Tempe',
#        'University of Arizona',
#        'Embry-Riddle Aeronautical University-Prescott',
#        'Northern Arizona University',
#        'California Institute of Technology',
#        'California State University-Chico',
#        'University of California-Berkeley',
#        'University of California-Davis',
#        'University of California-Irvine',
#        'University of California-Los Angeles',
#        'University of California-San Diego', 'Humboldt State University',
#        'Naval Postgraduate School', 'San Diego State University',
#        'San Francisco State University', 'San Jose State University',
#        'University of Southern California',
#        'University of Colorado Boulder',
# ...

# %%
csv_2009.columns
# Out:
# Index(['unitid', 'institution name', 'year',
#        'C2009_A.CIP Code -  2000 Classification', 'CipTitle',
#        'C2009_A.First or Second Major', 'C2009_A.Award Level code',
#        'C2009_A_RV.Grand total', 'C2009_A_RV.Grand total men',
#        'C2009_A_RV.Grand total women',
#        'C2009_A_RV.American Indian or Alaska Native total - derived',
#        'C2009_A_RV.American Indian or Alaska Native men - derived',
#        'C2009_A_RV.American Indian or Alaska Native women - derived',
#        'C2009_A_RV.Asian/Native Hawaiian/Other Pacific Islander total - derived',
#        'C2009_A_RV.Asian/Native Hawaiian/Other Pacific Islander men - derived',
#        'C2009_A_RV.Asian/Native Hawaiian/Other Pacific Islander women - derived',
#        'C2009_A_RV.Black or African American/Black non-Hispanic total - derived',
#        'C2009_A_RV.Black or African American/Black non-Hispanic men - derived',
# ...

# %%
np.sum([\
    csv_2009[
        (csv_2009['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2009['C2009_A.CIP Code -  2000 Classification'] == "'40.04'")&
        (csv_2009['C2009_A.Award Level code']=="Bachelor's degree")
            ]['C2009_A_RV.Grand total'].values[0],

    csv_2010[
        (csv_2010['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2010['C2010_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2010['C2010_A.Award Level code']=="Bachelor's degree")
            ]['C2010_A_RV.Grand total'].values[0],

    csv_2011[
        (csv_2011['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2011['C2011_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2011['C2011_A.Award Level code']=="Bachelor's degree")
            ]['C2011_A_RV.Grand total'].values[0],

    csv_2012[
        (csv_2012['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2012['C2012_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2012['C2012_A.Award Level code']=="Bachelor's degree")
            ]['C2012_A_RV.Grand total'].values[0],

    csv_2013[
        (csv_2013['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2013['C2013_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2013['C2013_A.Award Level code']=="Bachelor's degree")
            ]['C2013_A_RV.Grand total'].values[0],

    csv_2014[
        (csv_2014['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2014['C2014_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2014['C2014_A.Award Level code']=="Bachelor's degree")
            ]['C2014_A_RV.Grand total'].values[0],

    csv_2015[
        (csv_2015['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2015['C2015_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2015['C2015_A.Award Level code']=="Bachelor's degree")
            ]['C2015_A_RV.Grand total'].values[0],

    csv_2016[
        (csv_2016['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2016['C2016_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2016['C2016_A.Award Level code']=="Bachelor's degree")
            ]['C2016_A_RV.Grand total'].values[0],

    csv_2017[
        (csv_2017['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2017['C2017_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2017['C2017_A.Award Level code']=="Bachelor's degree")
            ]['C2017_A_RV.Grand total'].values[0],

    csv_2018[
        (csv_2018['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2018['C2018_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2018['C2018_A.Award Level code']=="Bachelor's degree")
            ]['C2018_A_RV.Grand total'].values[0],

    csv_2019[
        (csv_2019['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2019['C2019_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2019['C2019_A.Award Level code']=="Bachelor's degree")
            ]['C2019_A.Grand total'].values[0],
        
    #csv_2020[
    #    (csv_2020['institution name']=='Pennsylvania State University-Main Campus')&
    #    (csv_2020['C2020_A.CIP Code -  2020 Classification'] == "'40.04'")&
    #    (csv_2020['C2020_A.Award Level code']=="Bachelor's degree")
    #        ]['C2020_A.Grand total'].values[0],
       ])
# Out:
# 542

# %%
np.sum([\
    csv_2009[
        (csv_2009['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2009['C2009_A.CIP Code -  2000 Classification'] == "'40.04'")&
        (csv_2009['C2009_A.Award Level code']=="Bachelor's degree")
            ]['C2009_A_RV.Hispanic or Latino/Hispanic total - derived'].values[0],

    csv_2010[
        (csv_2010['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2010['C2010_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2010['C2010_A.Award Level code']=="Bachelor's degree")
            ]['C2010_A_RV.Hispanic or Latino/Hispanic total - derived'].values[0],

    csv_2011[
        (csv_2011['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2011['C2011_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2011['C2011_A.Award Level code']=="Bachelor's degree")
            ]['C2011_A_RV.Hispanic or Latino total'].values[0],

    csv_2012[
        (csv_2012['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2012['C2012_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2012['C2012_A.Award Level code']=="Bachelor's degree")
            ]['C2012_A_RV.Hispanic or Latino total'].values[0],

    csv_2013[
        (csv_2013['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2013['C2013_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2013['C2013_A.Award Level code']=="Bachelor's degree")
            ]['C2013_A_RV.Hispanic or Latino total'].values[0],

    csv_2014[
        (csv_2014['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2014['C2014_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2014['C2014_A.Award Level code']=="Bachelor's degree")
            ]['C2014_A_RV.Hispanic or Latino total'].values[0],

    csv_2015[
        (csv_2015['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2015['C2015_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2015['C2015_A.Award Level code']=="Bachelor's degree")
            ]['C2015_A_RV.Hispanic or Latino total'].values[0],

    csv_2016[
        (csv_2016['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2016['C2016_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2016['C2016_A.Award Level code']=="Bachelor's degree")
            ]['C2016_A_RV.Hispanic or Latino total'].values[0],

    csv_2017[
        (csv_2017['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2017['C2017_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2017['C2017_A.Award Level code']=="Bachelor's degree")
            ]['C2017_A_RV.Hispanic or Latino total'].values[0],

    csv_2018[
        (csv_2018['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2018['C2018_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2018['C2018_A.Award Level code']=="Bachelor's degree")
            ]['C2018_A_RV.Hispanic or Latino total'].values[0],

    csv_2019[
        (csv_2019['institution name']=='Pennsylvania State University-Main Campus')&
        (csv_2019['C2019_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2019['C2019_A.Award Level code']=="Bachelor's degree")
            ]['C2019_A.Hispanic or Latino total'].values[0],
        
    #csv_2020[
    #    (csv_2020['institution name']=='Pennsylvania State University-Main Campus')&
    #    (csv_2020['C2020_A.CIP Code -  2020 Classification'] == "'40.04'")&
    #    (csv_2020['C2020_A.Award Level code']=="Bachelor's degree")
    #        ]['C2020_A.Hispanic or Latino total'].values[0],
       ])
# Out:
# 17

# %%
np.sum([\
    csv_2009[
        (csv_2009['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2009['C2009_A.CIP Code -  2000 Classification'] == "'40.04'")&
        (csv_2009['C2009_A.Award Level code']=="Bachelor's degree")
            ]['C2009_A_RV.Grand total'].values[0],

    csv_2010[
        (csv_2010['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2010['C2010_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2010['C2010_A.Award Level code']=="Bachelor's degree")
            ]['C2010_A_RV.Grand total'].values[0],

    csv_2011[
        (csv_2011['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2011['C2011_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2011['C2011_A.Award Level code']=="Bachelor's degree")
            ]['C2011_A_RV.Grand total'].values[0],

    csv_2012[
        (csv_2012['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2012['C2012_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2012['C2012_A.Award Level code']=="Bachelor's degree")
            ]['C2012_A_RV.Grand total'].values[0],

    csv_2013[
        (csv_2013['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2013['C2013_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2013['C2013_A.Award Level code']=="Bachelor's degree")
            ]['C2013_A_RV.Grand total'].values[0],

    csv_2014[
        (csv_2014['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2014['C2014_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2014['C2014_A.Award Level code']=="Bachelor's degree")
            ]['C2014_A_RV.Grand total'].values[0],

    csv_2015[
        (csv_2015['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2015['C2015_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2015['C2015_A.Award Level code']=="Bachelor's degree")
            ]['C2015_A_RV.Grand total'].values[0],

    csv_2016[
        (csv_2016['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2016['C2016_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2016['C2016_A.Award Level code']=="Bachelor's degree")
            ]['C2016_A_RV.Grand total'].values[0],

    csv_2017[
        (csv_2017['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2017['C2017_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2017['C2017_A.Award Level code']=="Bachelor's degree")
            ]['C2017_A_RV.Grand total'].values[0],

    csv_2018[
        (csv_2018['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2018['C2018_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2018['C2018_A.Award Level code']=="Bachelor's degree")
            ]['C2018_A_RV.Grand total'].values[0],

    csv_2019[
        (csv_2019['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2019['C2019_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2019['C2019_A.Award Level code']=="Bachelor's degree")
            ]['C2019_A.Grand total'].values[0],
        
    csv_2020[
        (csv_2020['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2020['C2020_A.CIP Code -  2020 Classification'] == "'40.04'")&
        (csv_2020['C2020_A.Award Level code']=="Bachelor's degree")
            ]['C2020_A.Grand total'].values[0],
       ])
# Out:
# 448

# %%
np.sum([\
    csv_2009[
        (csv_2009['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2009['C2009_A.CIP Code -  2000 Classification'] == "'40.04'")&
        (csv_2009['C2009_A.Award Level code']=="Bachelor's degree")
            ]['C2009_A_RV.Hispanic or Latino/Hispanic total - derived'].values[0],

    csv_2010[
        (csv_2010['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2010['C2010_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2010['C2010_A.Award Level code']=="Bachelor's degree")
            ]['C2010_A_RV.Hispanic or Latino/Hispanic total - derived'].values[0],

    csv_2011[
        (csv_2011['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2011['C2011_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2011['C2011_A.Award Level code']=="Bachelor's degree")
            ]['C2011_A_RV.Hispanic or Latino total'].values[0],

    csv_2012[
        (csv_2012['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2012['C2012_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2012['C2012_A.Award Level code']=="Bachelor's degree")
            ]['C2012_A_RV.Hispanic or Latino total'].values[0],

    csv_2013[
        (csv_2013['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2013['C2013_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2013['C2013_A.Award Level code']=="Bachelor's degree")
            ]['C2013_A_RV.Hispanic or Latino total'].values[0],

    csv_2014[
        (csv_2014['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2014['C2014_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2014['C2014_A.Award Level code']=="Bachelor's degree")
            ]['C2014_A_RV.Hispanic or Latino total'].values[0],

    csv_2015[
        (csv_2015['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2015['C2015_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2015['C2015_A.Award Level code']=="Bachelor's degree")
            ]['C2015_A_RV.Hispanic or Latino total'].values[0],

    csv_2016[
        (csv_2016['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2016['C2016_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2016['C2016_A.Award Level code']=="Bachelor's degree")
            ]['C2016_A_RV.Hispanic or Latino total'].values[0],

    csv_2017[
        (csv_2017['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2017['C2017_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2017['C2017_A.Award Level code']=="Bachelor's degree")
            ]['C2017_A_RV.Hispanic or Latino total'].values[0],

    csv_2018[
        (csv_2018['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2018['C2018_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2018['C2018_A.Award Level code']=="Bachelor's degree")
            ]['C2018_A_RV.Hispanic or Latino total'].values[0],

    csv_2019[
        (csv_2019['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2019['C2019_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2019['C2019_A.Award Level code']=="Bachelor's degree")
            ]['C2019_A.Hispanic or Latino total'].values[0],
        
    csv_2020[
        (csv_2020['institution name']=='University of Oklahoma-Norman Campus')&
        (csv_2020['C2020_A.CIP Code -  2020 Classification'] == "'40.04'")&
        (csv_2020['C2020_A.Award Level code']=="Bachelor's degree")
            ]['C2020_A.Hispanic or Latino total'].values[0],
       ])
# Out:
# 18

# %%
np.sum([\
    csv_2009[
        (csv_2009['institution name']=='Texas A & M University-College Station')&
        (csv_2009['C2009_A.CIP Code -  2000 Classification'] == "'40.04'")&
        (csv_2009['C2009_A.Award Level code']=="Bachelor's degree")
            ]['C2009_A_RV.Grand total'].values[0],

    csv_2010[
        (csv_2010['institution name']=='Texas A & M University-College Station')&
        (csv_2010['C2010_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2010['C2010_A.Award Level code']=="Bachelor's degree")
            ]['C2010_A_RV.Grand total'].values[0],

    csv_2011[
        (csv_2011['institution name']=='Texas A & M University-College Station')&
        (csv_2011['C2011_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2011['C2011_A.Award Level code']=="Bachelor's degree")
            ]['C2011_A_RV.Grand total'].values[0],

    csv_2012[
        (csv_2012['institution name']=='Texas A & M University-College Station')&
        (csv_2012['C2012_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2012['C2012_A.Award Level code']=="Bachelor's degree")
            ]['C2012_A_RV.Grand total'].values[0],

    csv_2013[
        (csv_2013['institution name']=='Texas A & M University-College Station')&
        (csv_2013['C2013_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2013['C2013_A.Award Level code']=="Bachelor's degree")
            ]['C2013_A_RV.Grand total'].values[0],

    csv_2014[
        (csv_2014['institution name']=='Texas A & M University-College Station')&
        (csv_2014['C2014_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2014['C2014_A.Award Level code']=="Bachelor's degree")
            ]['C2014_A_RV.Grand total'].values[0],

    csv_2015[
        (csv_2015['institution name']=='Texas A & M University-College Station')&
        (csv_2015['C2015_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2015['C2015_A.Award Level code']=="Bachelor's degree")
            ]['C2015_A_RV.Grand total'].values[0],

    csv_2016[
        (csv_2016['institution name']=='Texas A & M University-College Station')&
        (csv_2016['C2016_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2016['C2016_A.Award Level code']=="Bachelor's degree")
            ]['C2016_A_RV.Grand total'].values[0],

    csv_2017[
        (csv_2017['institution name']=='Texas A & M University-College Station')&
        (csv_2017['C2017_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2017['C2017_A.Award Level code']=="Bachelor's degree")
            ]['C2017_A_RV.Grand total'].values[0],

    csv_2018[
        (csv_2018['institution name']=='Texas A & M University-College Station')&
        (csv_2018['C2018_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2018['C2018_A.Award Level code']=="Bachelor's degree")
            ]['C2018_A_RV.Grand total'].values[0],

    csv_2019[
        (csv_2019['institution name']=='Texas A & M University-College Station')&
        (csv_2019['C2019_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2019['C2019_A.Award Level code']=="Bachelor's degree")
            ]['C2019_A.Grand total'].values[0],
        
    csv_2020[
        (csv_2020['institution name']=='Texas A & M University-College Station')&
        (csv_2020['C2020_A.CIP Code -  2020 Classification'] == "'40.04'")&
        (csv_2020['C2020_A.Award Level code']=="Bachelor's degree")
            ]['C2020_A.Grand total'].values[0],
       ])
# Out:
# 325

# %%
np.sum([\
    csv_2009[
        (csv_2009['institution name']=='Texas A & M University-College Station')&
        (csv_2009['C2009_A.CIP Code -  2000 Classification'] == "'40.04'")&
        (csv_2009['C2009_A.Award Level code']=="Bachelor's degree")
            ]['C2009_A_RV.Hispanic or Latino/Hispanic total - derived'].values[0],

    csv_2010[
        (csv_2010['institution name']=='Texas A & M University-College Station')&
        (csv_2010['C2010_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2010['C2010_A.Award Level code']=="Bachelor's degree")
            ]['C2010_A_RV.Hispanic or Latino/Hispanic total - derived'].values[0],

    csv_2011[
        (csv_2011['institution name']=='Texas A & M University-College Station')&
        (csv_2011['C2011_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2011['C2011_A.Award Level code']=="Bachelor's degree")
            ]['C2011_A_RV.Hispanic or Latino total'].values[0],

    csv_2012[
        (csv_2012['institution name']=='Texas A & M University-College Station')&
        (csv_2012['C2012_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2012['C2012_A.Award Level code']=="Bachelor's degree")
            ]['C2012_A_RV.Hispanic or Latino total'].values[0],

    csv_2013[
        (csv_2013['institution name']=='Texas A & M University-College Station')&
        (csv_2013['C2013_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2013['C2013_A.Award Level code']=="Bachelor's degree")
            ]['C2013_A_RV.Hispanic or Latino total'].values[0],

    csv_2014[
        (csv_2014['institution name']=='Texas A & M University-College Station')&
        (csv_2014['C2014_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2014['C2014_A.Award Level code']=="Bachelor's degree")
            ]['C2014_A_RV.Hispanic or Latino total'].values[0],

    csv_2015[
        (csv_2015['institution name']=='Texas A & M University-College Station')&
        (csv_2015['C2015_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2015['C2015_A.Award Level code']=="Bachelor's degree")
            ]['C2015_A_RV.Hispanic or Latino total'].values[0],

    csv_2016[
        (csv_2016['institution name']=='Texas A & M University-College Station')&
        (csv_2016['C2016_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2016['C2016_A.Award Level code']=="Bachelor's degree")
            ]['C2016_A_RV.Hispanic or Latino total'].values[0],

    csv_2017[
        (csv_2017['institution name']=='Texas A & M University-College Station')&
        (csv_2017['C2017_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2017['C2017_A.Award Level code']=="Bachelor's degree")
            ]['C2017_A_RV.Hispanic or Latino total'].values[0],

    csv_2018[
        (csv_2018['institution name']=='Texas A & M University-College Station')&
        (csv_2018['C2018_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2018['C2018_A.Award Level code']=="Bachelor's degree")
            ]['C2018_A_RV.Hispanic or Latino total'].values[0],

    csv_2019[
        (csv_2019['institution name']=='Texas A & M University-College Station')&
        (csv_2019['C2019_A.CIP Code -  2010 Classification'] == "'40.04'")&
        (csv_2019['C2019_A.Award Level code']=="Bachelor's degree")
            ]['C2019_A.Hispanic or Latino total'].values[0],
        
    csv_2020[
        (csv_2020['institution name']=='Texas A & M University-College Station')&
        (csv_2020['C2020_A.CIP Code -  2020 Classification'] == "'40.04'")&
        (csv_2020['C2020_A.Award Level code']=="Bachelor's degree")
            ]['C2020_A.Hispanic or Latino total'].values[0],
       ])
# Out:
# 60
