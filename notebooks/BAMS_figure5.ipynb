# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import completions_module as cmodule

# %% [markdown]
# Load data.

# %%
# ucar list
all_files = glob.glob("../data/completions_*.csv")
all_files = sorted(all_files)
df_ucar = cmodule.open_and_concat(all_files)

# hsi list
all_files = glob.glob("../data/hsi_completions_*.csv")
all_files = sorted(all_files)
df_hsis = cmodule.open_and_concat(all_files)

# ehi list
all_files = glob.glob("../data/emerginghsi_completions_*.csv")
all_files = sorted(all_files)
df_ehis = cmodule.open_and_concat(all_files)

# %% [markdown]
# Concatenate the data from UCAR, HSI, EHI lists.

# %%
all_unis = pd.concat([df_ucar, df_hsis, df_ehis])

# %% [markdown]
# ## Earth and Atmospheric Sciences

# %%
# ---

df = cmodule.bs_degrees(all_unis)
df = cmodule.physical_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp1 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.bs_degrees(all_unis)
df = cmodule.earth_and_atmos_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp2 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.bs_degrees(all_unis)
df = cmodule.atmospheric_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp3 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.ms_degrees(all_unis)
df = cmodule.physical_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp4 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.ms_degrees(all_unis)
df = cmodule.earth_and_atmos_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp5 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.ms_degrees(all_unis)
df = cmodule.atmospheric_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp6 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.phd_degrees(all_unis)
df = cmodule.physical_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp7 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.phd_degrees(all_unis)
df = cmodule.earth_and_atmos_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp8 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
# ---

df = cmodule.phd_degrees(all_unis)
df = cmodule.atmospheric_sciences(df)

# ---

df_nonhis = cmodule.diff(
                 df.groupby('year').sum()['Grand total'], 
                 df.groupby('year').sum()['Hispanic or Latino total'], 
                 'Non-Hispanic total')['Non-Hispanic total']

# ---

df_his = df.groupby('year').sum()['Hispanic or Latino total']

# ----

tmp9 = pd.concat([df_nonhis, df_his], axis=1).mean()

# ----

# %%
explode = (0, 0.2)
colors = ['steelblue', 'skyblue']

#-----------------------%

fig = plt.figure(figsize=(8.,8.))

#-----------------------%

ax1 = fig.add_axes([0.0, 0.66, 0.3, 0.3])
ax1.set_title("a) Bachelor's degree \nPhysical Science",
              fontsize=12, y=0.91)

labels = 'Non-Hispanic', 'Hispanic/Latinx'

thepie = ax1.pie(tmp1.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=335, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax2 = fig.add_axes([0.33, 0.66, 0.3, 0.3])
ax2.set_title("b) Bachelor's degree \nEarth and Atmospheric Science",
              fontsize=12, y=0.91)

thepie = ax2.pie(tmp2.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=335, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax3 = fig.add_axes([0.66, 0.66, 0.3, 0.3])
ax3.set_title("c) Bachelor's degree \nAtmospheric Science",
              fontsize=12, y=0.91)

thepie = ax3.pie(tmp3.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=325, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax4 = fig.add_axes([0.0, 0.33, 0.3, 0.3])
ax4.set_title("d) Master's degree \nPhysical Science",
              fontsize=12, y=0.91)

thepie = ax4.pie(tmp4.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=320, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax5 = fig.add_axes([0.33, 0.33, 0.3, 0.3])
ax5.set_title("e) Master's degree \nEarth and Atmospheric Science",
              fontsize=12, y=0.91)

thepie = ax5.pie(tmp5.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=320, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax6 = fig.add_axes([0.66, 0.33, 0.3, 0.3])
ax6.set_title("f) Master's degree \nAtmospheric Science",
              fontsize=12, y=0.91)

thepie = ax6.pie(tmp6.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=320, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax7 = fig.add_axes([0.0, 0., 0.3, 0.3])
ax7.set_title("g) Doctoral degree \nPhysical Science",
              fontsize=12, y=0.91)

thepie = ax7.pie(tmp7.values, #labels=labels, 
        autopct='%1.1f%%', shadow=False, 
        startangle=320, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax8 = fig.add_axes([0.33, 0., 0.3, 0.3])
ax8.set_title("h) Doctoral degree \nEarth and Atmospheric Science",
              fontsize=12, y=0.91)

thepie = ax8.pie(tmp8.values,
        autopct='%1.1f%%', shadow=False,  
        startangle=320, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])
    
#-----------------------%

ax9 = fig.add_axes([0.66, 0., 0.3, 0.3])
ax9.set_title("i) Doctoral degree \nAtmospheric Science",
              fontsize=12, y=0.91)

thepie = ax9.pie(tmp9.values,
        autopct='%1.1f%%', shadow=False, 
        startangle=320, explode=explode, colors=colors,
        textprops={'color':"k", 'weight':'bold', 'fontsize':12})

for patch in thepie[0]:
    patch.set_path_effects([
        path_effects.SimplePatchShadow(offset=(3, -3), alpha=0.5,
                                       shadow_rgbFace='grey'),
        path_effects.Normal()])

ax9.legend([thepie[0][0], thepie[0][1]], 
           ['Non-Hispanic/Latinx', 'Hispanic/Latinx'],
           bbox_to_anchor=(0.35, -0.15), ncol=2, 
           loc='lower right', fontsize=12)

#-----------------------%

plt.savefig(f"../figures/fig5.png", bbox_inches='tight', dpi=500)
plt.show()

#-----------------------%
