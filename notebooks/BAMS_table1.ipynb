# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import completions_module as cmodule

# %% [markdown]
# Load data.

# %%
# ucar list
all_files = glob.glob("../data/completions_*.csv")
all_files = sorted(all_files)
df_ucar = cmodule.open_and_concat(all_files)

# hsi list
all_files = glob.glob("../data/hsi_completions_*.csv")
all_files = sorted(all_files)
df_hsis = cmodule.open_and_concat(all_files)

# ehi list
all_files = glob.glob("../data/emerginghsi_completions_*.csv")
all_files = sorted(all_files)
df_ehis = cmodule.open_and_concat(all_files)

# %% [markdown]
# Concatenate the data from UCAR, HSI, EHI lists.

# %%
all_unis = pd.concat([df_ucar, df_hsis, df_ehis])

# %% [markdown]
# ## Earth and Atmospheric Sciences

# %%
df = cmodule.bs_degrees(all_unis)
df = cmodule.earth_and_atmos_sciences(df)

school_names = df.groupby(
    'institution name').sum()['Hispanic or Latino total'].sort_values(
    ascending=False).head(30).index

df = df[df['institution name'].isin(school_names)].groupby(
    'institution name').sum()[['Grand total','Hispanic or Latino total']]

df['percent_total'] = np.around(
    (df['Hispanic or Latino total']/df['Grand total']) * 100, 1)

df.sort_values('Hispanic or Latino total',ascending=False).head(30)
# Out:
#                                                 Grand total  \
# institution name
# Texas A & M University-College Station                 1245
# University of Puerto Rico-Mayaguez                      171
# University of Houston                                   787
# The University of Texas at El Paso                      159
# The University of Texas at Austin                       703
# Florida International University                        152
# Pennsylvania State University-Main Campus              2195
# University of California-Santa Cruz                     581
# University of California-Irvine                         455
# The University of Texas at San Antonio                  279
# University of California-Santa Barbara                  442
# California State University-Fullerton                   283
# United States Naval Academy                             767
# California State University-Bakersfield                 192
# University of California-Los Angeles                    331
# Stanford University                                     434
# Texas Tech University                                   339
# University of Washington-Seattle Campus                1101
# Columbia University in the City of New York             343
# University of California-Davis                          392
# University of California-Berkeley                       362
# California State Polytechnic University-Pomona          181
# University of Arizona                                   420
# Florida State University                                421
# Texas A & M University-Kingsville                       122
# The University of Texas at Arlington                    302
# California State University-Los Angeles                  77
# Texas A & M University-Corpus Christi                   145
# Humboldt State University                               317
# University of Nevada-Las Vegas                          211
#
#                                                 Hispanic or Latino total  \
# institution name
# Texas A & M University-College Station                               208
# University of Puerto Rico-Mayaguez                                   166
# University of Houston                                                163
# The University of Texas at El Paso                                   114
# The University of Texas at Austin                                    102
# Florida International University                                      99
# Pennsylvania State University-Main Campus                             97
# University of California-Santa Cruz                                   91
# University of California-Irvine                                       86
# The University of Texas at San Antonio                                83
# University of California-Santa Barbara                                79
# California State University-Fullerton                                 76
# United States Naval Academy                                           75
# California State University-Bakersfield                               70
# University of California-Los Angeles                                  63
# Stanford University                                                   60
# Texas Tech University                                                 60
# University of Washington-Seattle Campus                               56
# Columbia University in the City of New York                           56
# University of California-Davis                                        54
# University of California-Berkeley                                     53
# California State Polytechnic University-Pomona                        52
# University of Arizona                                                 51
# Florida State University                                              49
# Texas A & M University-Kingsville                                     48
# The University of Texas at Arlington                                  47
# California State University-Los Angeles                               46
# Texas A & M University-Corpus Christi                                 43
# Humboldt State University                                             42
# University of Nevada-Las Vegas                                        40
#
#                                                 percent_total
# institution name
# Texas A & M University-College Station                   16.7
# University of Puerto Rico-Mayaguez                       97.1
# University of Houston                                    20.7
# The University of Texas at El Paso                       71.7
# The University of Texas at Austin                        14.5
# Florida International University                         65.1
# Pennsylvania State University-Main Campus                 4.4
# University of California-Santa Cruz                      15.7
# University of California-Irvine                          18.9
# The University of Texas at San Antonio                   29.7
# University of California-Santa Barbara                   17.9
# California State University-Fullerton                    26.9
# United States Naval Academy                               9.8
# California State University-Bakersfield                  36.5
# University of California-Los Angeles                     19.0
# Stanford University                                      13.8
# Texas Tech University                                    17.7
# University of Washington-Seattle Campus                   5.1
# Columbia University in the City of New York              16.3
# University of California-Davis                           13.8
# University of California-Berkeley                        14.6
# California State Polytechnic University-Pomona           28.7
# University of Arizona                                    12.1
# Florida State University                                 11.6
# Texas A & M University-Kingsville                        39.3
# The University of Texas at Arlington                     15.6
# California State University-Los Angeles                  59.7
# Texas A & M University-Corpus Christi                    29.7
# Humboldt State University                                13.2
# University of Nevada-Las Vegas                           19.0
