# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import completions_module as cmodule

# %% [markdown]
# Load data.

# %%
# ucar list
all_files = glob.glob("../data/completions_*.csv")
all_files = sorted(all_files)
df_ucar = cmodule.open_and_concat(all_files)

# hsi list
all_files = glob.glob("../data/hsi_completions_*.csv")
all_files = sorted(all_files)
df_hsis = cmodule.open_and_concat(all_files)

# ehi list
all_files = glob.glob("../data/emerginghsi_completions_*.csv")
all_files = sorted(all_files)
df_ehis = cmodule.open_and_concat(all_files)

# %% [markdown]
# Concatenate the data from UCAR, HSI, EHI lists.

# %%
all_unis = pd.concat([df_ucar, df_hsis, df_ehis])

# %% [markdown]
# ## Earth and Atmospheric Sciences

# %% [markdown]
# Table 1

# %%
df = cmodule.bs_degrees(all_unis)
df = cmodule.earth_and_atmos_sciences(df)

school_names = df.groupby(
    'institution name').sum()['Hispanic or Latino total'].sort_values(
    ascending=False).head(30).index

df = df[df['institution name'].isin(school_names)].groupby(
    'institution name').sum()[['Grand total','Hispanic or Latino total']]

df['percent_total'] = np.around(
    (df['Hispanic or Latino total']/df['Grand total']) * 100, 1)

df.sort_values('Hispanic or Latino total',ascending=False).head(
    30).drop(columns=['Grand total'])
# Out:
#                                                 Hispanic or Latino total  \
# institution name
# Texas A & M University-College Station                               233
# University of Puerto Rico-Mayaguez                                   181
# University of Houston                                                174
# The University of Texas at El Paso                                   129
# University of California-Santa Cruz                                  114
# Florida International University                                     111
# The University of Texas at Austin                                    109
# University of California-Irvine                                      105
# Pennsylvania State University-Main Campus                             97
# The University of Texas at San Antonio                                96
# University of California-Santa Barbara                                93
# California State University-Fullerton                                 91
# California State University-Bakersfield                               81
# United States Naval Academy                                           80
# University of California-Los Angeles                                  71
# Stanford University                                                   67
# Texas Tech University                                                 67
# University of Washington-Seattle Campus                               64
# University of California-Davis                                        60
# Columbia University in the City of New York                           60
# University of Arizona                                                 59
# University of California-Berkeley                                     59
# California State Polytechnic University-Pomona                        59
# The University of Texas at Arlington                                  57
# California State University-Los Angeles                               55
# University of Nevada-Las Vegas                                        52
# Texas A & M University-Kingsville                                     50
# Florida State University                                              49
# Texas A & M University-Corpus Christi                                 47
# California State University-San Bernardino                            47
#
#                                                 percent_total
# institution name
# Texas A & M University-College Station                   17.3
# University of Puerto Rico-Mayaguez                       96.8
# University of Houston                                    20.8
# The University of Texas at El Paso                       72.5
# University of California-Santa Cruz                      17.6
# Florida International University                         66.5
# The University of Texas at Austin                        14.6
# University of California-Irvine                          20.7
# Pennsylvania State University-Main Campus                 4.4
# The University of Texas at San Antonio                   31.7
# University of California-Santa Barbara                   18.2
# California State University-Fullerton                    28.3
# California State University-Bakersfield                  37.3
# United States Naval Academy                              10.0
# University of California-Los Angeles                     19.3
# Stanford University                                      14.4
# Texas Tech University                                    17.9
# University of Washington-Seattle Campus                   5.2
# University of California-Davis                           14.2
# Columbia University in the City of New York              16.4
# University of Arizona                                    12.2
# University of California-Berkeley                        15.3
# California State Polytechnic University-Pomona           29.1
# The University of Texas at Arlington                     17.2
# California State University-Los Angeles                  63.2
# University of Nevada-Las Vegas                           20.6
# Texas A & M University-Kingsville                        39.7
# Florida State University                                 10.9
# Texas A & M University-Corpus Christi                    29.9
# California State University-San Bernardino               34.1

# %% [markdown]
# Supplementary Table 6

# %%
df = cmodule.bs_degrees(all_unis)
df = cmodule.earth_and_atmos_sciences(df)

school_names = df.groupby(
    'institution name').sum()['Grand total'].sort_values(
    ascending=False).head(30).index

df = df[df['institution name'].isin(school_names)].groupby(
    'institution name').sum()[['Grand total']]

df.sort_values('Grand total',ascending=False).head(30)
# Out:
#                                                     Grand total
# institution name
# Pennsylvania State University-Main Campus                  2195
# Texas A & M University-College Station                     1346
# University of Washington-Seattle Campus                    1237
# Mississippi State University                                943
# University of Houston                                       837
# United States Naval Academy                                 802
# University of Oklahoma-Norman Campus                        749
# The University of Texas at Austin                           745
# University of California-Santa Cruz                         647
# University of North Carolina at Charlotte                   635
# University of Wisconsin-Madison                             630
# North Carolina State University at Raleigh                  595
# University of Colorado Boulder                              589
# University of California-Santa Barbara                      511
# University of California-Irvine                             507
# Washington State University                                 497
# University of Arizona                                       482
# Montana State University                                    480
# Stanford University                                         465
# Virginia Polytechnic Institute and State Univer...          465
# University of Wyoming                                       450
# Florida State University                                    448
# University of Missouri-Columbia                             445
# University of Michigan-Ann Arbor                            441
# University of Illinois at Urbana-Champaign                  434
# University of California-Davis                              424
# Ohio State University-Main Campus                           422
# Millersville University of Pennsylvania                     419
# Northern Illinois University                                412
# University of California-Berkeley                           386
