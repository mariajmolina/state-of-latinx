# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import completions_module as cmodule

# %% [markdown]
# Load data.

# %%
# ucar list
all_files = glob.glob("../data/completions_*.csv")
all_files = sorted(all_files)
df_ucar = cmodule.open_and_concat(all_files)

# hsi list
all_files = glob.glob("../data/hsi_completions_*.csv")
all_files = sorted(all_files)
df_hsis = cmodule.open_and_concat(all_files)

# ehi list
all_files = glob.glob("../data/emerginghsi_completions_*.csv")
all_files = sorted(all_files)
df_ehis = cmodule.open_and_concat(all_files)

# %% [markdown]
# Concatenate the data from UCAR, HSI, EHI lists.

# %%
all_unis = pd.concat([df_ucar, df_hsis, df_ehis])

# %% [markdown]
# ## Atmospheric Sciences

# %%
df = cmodule.bs_degrees(all_unis)
df = cmodule.atmospheric_sciences(df)

school_names = df.groupby(
    'institution name').sum()['Hispanic or Latino total'].sort_values(
    ascending=False).head(30).index

df = df[df['institution name'].isin(school_names)].groupby(
    'institution name').sum()[['Grand total','Hispanic or Latino total']]

df['percent_total'] = np.around(
    (df['Hispanic or Latino total']/df['Grand total']) * 100, 1)

df.sort_values('Hispanic or Latino total',ascending=False).head(30)
# Out:
#                                                     Grand total  \
# institution name
# Texas A & M University-College Station                      298
# Florida State University                                    295
# University of the Incarnate Word                             44
# University of California-Los Angeles                        138
# University of Illinois at Urbana-Champaign                  192
# Pennsylvania State University-Main Campus                   542
# SUNY Maritime College                                       128
# University of Oklahoma-Norman Campus                        416
# Embry-Riddle Aeronautical University-Daytona Beach          220
# Cornell University                                          112
# Northern Illinois University                                180
# San Jose State University                                    65
# University of Washington-Seattle Campus                     185
# University of Miami                                          73
# Virginia Polytechnic Institute and State Univer...          161
# Valparaiso University                                       249
# Rutgers University-New Brunswick                            158
# SUNY College at Oswego                                      154
# Stony Brook University                                       97
# SUNY at Albany                                              128
# North Carolina State University at Raleigh                  245
# University of Missouri-Columbia                             305
# Embry-Riddle Aeronautical University-Prescott                87
# University of California-Davis                               51
# University of South Alabama                                 151
# United States Air Force Academy                              72
# University of Louisiana at Monroe                            71
# Purdue University-Main Campus                                98
# Millersville University of Pennsylvania                     229
# University of Kansas                                        109
#
#                                                     Hispanic or Latino total  \
# institution name
# Texas A & M University-College Station                                    53
# Florida State University                                                  35
# University of the Incarnate Word                                          23
# University of California-Los Angeles                                      21
# University of Illinois at Urbana-Champaign                                18
# Pennsylvania State University-Main Campus                                 17
# SUNY Maritime College                                                     15
# University of Oklahoma-Norman Campus                                      15
# Embry-Riddle Aeronautical University-Daytona Beach                        14
# Cornell University                                                        14
# Northern Illinois University                                              12
# San Jose State University                                                 12
# University of Washington-Seattle Campus                                   12
# University of Miami                                                       12
# Virginia Polytechnic Institute and State Univer...                        10
# Valparaiso University                                                      9
# Rutgers University-New Brunswick                                           9
# SUNY College at Oswego                                                     8
# Stony Brook University                                                     8
# SUNY at Albany                                                             8
# North Carolina State University at Raleigh                                 7
# University of Missouri-Columbia                                            7
# Embry-Riddle Aeronautical University-Prescott                              7
# University of California-Davis                                             6
# University of South Alabama                                                6
# United States Air Force Academy                                            5
# University of Louisiana at Monroe                                          5
# Purdue University-Main Campus                                              5
# Millersville University of Pennsylvania                                    5
# University of Kansas                                                       5
#
#                                                     percent_total
# institution name
# Texas A & M University-College Station                       17.8
# Florida State University                                     11.9
# University of the Incarnate Word                             52.3
# University of California-Los Angeles                         15.2
# University of Illinois at Urbana-Champaign                    9.4
# Pennsylvania State University-Main Campus                     3.1
# SUNY Maritime College                                        11.7
# University of Oklahoma-Norman Campus                          3.6
# Embry-Riddle Aeronautical University-Daytona Beach            6.4
# Cornell University                                           12.5
# Northern Illinois University                                  6.7
# San Jose State University                                    18.5
# University of Washington-Seattle Campus                       6.5
# University of Miami                                          16.4
# Virginia Polytechnic Institute and State Univer...            6.2
# Valparaiso University                                         3.6
# Rutgers University-New Brunswick                              5.7
# SUNY College at Oswego                                        5.2
# Stony Brook University                                        8.2
# SUNY at Albany                                                6.2
# North Carolina State University at Raleigh                    2.9
# University of Missouri-Columbia                               2.3
# Embry-Riddle Aeronautical University-Prescott                 8.0
# University of California-Davis                               11.8
# University of South Alabama                                   4.0
# United States Air Force Academy                               6.9
# University of Louisiana at Monroe                             7.0
# Purdue University-Main Campus                                 5.1
# Millersville University of Pennsylvania                       2.2
# University of Kansas                                          4.6
